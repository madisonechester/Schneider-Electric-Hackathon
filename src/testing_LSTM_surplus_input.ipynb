# 2       -10097.0       -37.0     -4641.0    -27599.0      3       0       0
# 3       -15200.0      -192.0     -4617.0    -26921.0      3       0       0
# 4       -22582.0      -406.0     -4885.0    -27053.0      3       0       0
# ...          ...         ...         ...         ...    ...     ...     ...
# 8755     -8475.0     -1948.0     -4261.0    -28405.0      3       0       0
# 8756      1098.0     -1986.0     -4615.0    -26192.0      2       0       0
# 8757      6848.0     -1732.0     -4565.0    -24637.0      2       0       0
# 8758      3563.0     -1198.0     -4966.0    -24476.0      2       0       0
# 8759      5208.0      -610.0     -5104.0    -27119.0      2       0       0
#
#       winter  day_of_week  is_weekend
# 0          1            5           1
# 1          1            5           1
# 2          1            5           1
# 3          1            5           1
# 4          1            5           1
# ...      ...          ...         ...
# 8755       1            5           1
# 8756       1            5           1
# 8757       1            5           1
# 8758       1            5           1
# 8759       1            5           1
#
# [8760 rows x 32 columns]

# %%
df.interpolate(method='linear', limit_direction='both', inplace=True)
# Out:
# C:\Users\adria\AppData\Local\Temp\ipykernel_5300\1377071238.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   df.interpolate(method='linear', limit_direction='both', inplace=True)

# %%
any_nan = df.isna().any().any()

if any_nan:
    print("There are NaN values in the DataFrame.")
else:
    print("There are no NaN values in the DataFrame.")


nan_locations = np.argwhere(pd.isna(df))

if nan_locations.any():
    print("NaN values are present in the DataFrame.")
    print("Locations of NaN values:")
    print(nan_locations)
else:
    print("There are no NaN values in the DataFrame.")
# Out:
# There are no NaN values in the DataFrame.
# There are no NaN values in the DataFrame.

# %%
# NAN & 0 heatmap

# folder = r'data'
# file_name = 'final_data.csv'
# df = pd.read_csv(os.path.join(folder, file_name)) # change your df

df = df

# Plot NaN values and zeros heatmap
plt.figure(figsize=(6, 4))
cmap = sns.color_palette("viridis", as_cmap=True)
sns.heatmap(df.isnull(), cmap='viridis', cbar=False) # drop the nulls
# sns.heatmap(df == 0, cmap='viridis', cbar=False) # drop the 0
# sns.heatmap(df.isnull() | (df == 0), cmap=cmap, cbar=False) # drop both
plt.title('NaN and Zero Values Heatmap')
plt.show()

# %%
#X--> We create an array with 8 countries and 8759 hours of 7 features.
# y--> The surplus will be our target, so we created another array of 8 countries and 8769 hours using the surplus column
countries = ['HU', 'IT', 'PO', 'SP', 'DE', 'DK', 'SE', 'NE']
labels_countries = {
    'SP': 0, # Spain
    'UK': 1, # United Kingdom
    'DE': 2, # Germany
    'DK': 3, # Denmark
    'HU': 5, # Hungary
    'SE': 4, # Sweden
    'IT': 6, # Italy
    'PO': 7, # Poland
    'NL': 8 # Netherlands
}
num_countries = len(countries)

features = ['Hour', 'spring', 'summer', 'winter', 'day_of_week', 'is_weekend',
    'DEgen', 'DKgen',  'HUgen', 'ITgen', 'NEgen',  'POgen', 'SEgen', 'SPgen',
    'DEload', 'DKload', 'HUload', 'ITload', 'NEload', 'POload', 'SEload', 'SPload', 
    'DE_surplus',  'DK_surplus', 'HU_surplus', 'IT_surplus', 'NE_surplus', 'PO_surplus', 'SE_surplus', 'SP_surplus'  
]

# we drop spain
# features = ['Hour', 'spring', 'summer', 'winter', 'day_of_week', 'is_weekend',
#     'DEgen', 'DKgen',  'HUgen', 'ITgen', 'NEgen',  'POgen', 'SEgen',
#     'DEload', 'DKload', 'HUload', 'ITload', 'NEload', 'POload', 'SEload', 
#     'DE_surplus',  'DK_surplus', 'HU_surplus', 'IT_surplus', 'NE_surplus', 'PO_surplus', 'SE_surplus',
# ]


num_features = len(features)

label_column = 'label'


print('num_features: ', num_features)
print('num_countries: ', num_countries)
# Out:
# num_features:  30
# num_countries:  8

# %%
df[label_column].value_counts()
# Out:
# label
# 3    6968
# 4    1449
# 2     232
# 0     111
# Name: count, dtype: int64

# %% [markdown]
# ### Split

# %%
def train_val_test_df_split(perc, df):

    # split df
    # test
    split = int(df.shape[0]*perc)
    df_aux = df[:split]
    df_test = df[split:]

    # train and validation
    split = int(df_aux.shape[0]*perc)
    df_train = df_aux[:split]
    df_val = df_aux[split:]

    return df_train, df_val, df_test


perc = 0.8
df_train, df_val, df_test = train_val_test_df_split(perc, df)

print("Shapes:")
print("df_train:", df_train.shape)
print('==================')
print("df_val:", df_val.shape)
print('==================')
print("df_test:", df_test.shape)
# Out:
# Shapes:
# df_train: (5606, 32)
# ==================
# df_val: (1402, 32)
# ==================
# df_test: (1752, 32)

# %% [markdown]
# ### Checking the distribution for each feature

# %%
# import matplotlib.pyplot as plt

# # List of features to compare
# features_to_compare = [
#     'Hour', 'DEgen', 'DEload', 'DKgen', 'DKload', 'HUgen', 'HUload',
#     'ITgen', 'ITload', 'NEgen', 'NEload', 'POgen', 'POload', 'SEgen',
#     'SEload', 'SPgen', 'SPload', 'HU_surplus', 'IT_surplus', 'PO_surplus',
#     'SP_surplus', 'DE_surplus', 'DK_surplus', 'SE_surplus', 'NE_surplus',
#     'day_of_week'
# ]

# # Assuming scaled_df_train, scaled_df_val, and scaled_df_test are your DataFrames
# dfs = [df_train, df_val, df_test]
# df_names = ['df_train', 'df_val', 'df_test']

# # Plot histograms for each feature and each DataFrame
# for feature in features_to_compare:
#     plt.figure(figsize=(15, 5))
#     for i, (df, df_name) in enumerate(zip(dfs, df_names), 1):
#         plt.subplot(1, 3, i)
#         df[feature].hist(bins=20, alpha=0.7, label=df_name)
#         plt.title(f'{feature} - {df_name}')
#         plt.legend()
#     plt.show()

# %% [markdown]
# ### Scaling

# %%
from sklearn.preprocessing import MinMaxScaler

features_to_scale = [
    'Hour', 'DEgen', 'DEload', 'DKgen', 'DKload', 'HUgen', 'HUload',
    'ITgen', 'ITload', 'NEgen', 'NEload', 'POgen', 'POload', 'SEgen',
    'SEload', 'SPgen', 'SPload', 'HU_surplus', 'IT_surplus', 'PO_surplus',
    'SP_surplus', 'DE_surplus', 'DK_surplus', 'SE_surplus', 'NE_surplus',
    'day_of_week'
]

def scale_data(features_to_scale, df_train, df_val, df_test):
    
    scaler = MinMaxScaler()
    
    # Fit the scaler on training data and transform the features
    df_train[features_to_scale] = scaler.fit_transform(df_train[features_to_scale])
    
    # Transform validation and test data using the scaler fitted on training data
    df_val[features_to_scale] = scaler.transform(df_val[features_to_scale])
    df_test[features_to_scale] = scaler.transform(df_test[features_to_scale])

    return df_train, df_val, df_test

# Usage example
scaled_df_train, scaled_df_val, scaled_df_test = scale_data(features_to_scale, df_train, df_val, df_test)
# Out:
# C:\Users\adria\AppData\Local\Temp\ipykernel_5300\1111324500.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test[features_to_scale] = scaler.transform(df_test[features_to_scale])

# %% [markdown]
# ### Checking distributions in train, test and val

# %%
# # List of features to plot histograms for
# features_to_plot = [
#     'Hour', 'DEgen', 'DEload', 'DKgen', 'DKload', 'HUgen', 'HUload',
#     'ITgen', 'ITload', 'NEgen', 'NEload', 'POgen', 'POload', 'SEgen',
#     'SEload', 'SPgen', 'SPload', 'HU_surplus', 'IT_surplus', 'PO_surplus',
#     'SP_surplus', 'DE_surplus', 'DK_surplus', 'SE_surplus', 'NE_surplus',
#     'day_of_week'
# ]

# # Assuming scaled_df_train, scaled_df_val, and scaled_df_test are your DataFrames
# dfs = [scaled_df_train, scaled_df_val, scaled_df_test]
# df_names = ['scaled_df_train', 'scaled_df_val', 'scaled_df_test']

# # Plot histograms for each DataFrame
# for df, df_name in zip(dfs, df_names):
#     plt.figure(figsize=(15, 10))
#     for i, feature in enumerate(features_to_plot, 1):
#         plt.subplot(5, 6, i)
#         df[feature].hist(bins=20)
#         plt.title(feature)
#     plt.suptitle(f'Histograms for {df_name}')
#     plt.tight_layout(rect=[0, 0.03, 1, 0.95])
#     plt.show()


# # List of features to compare
# features_to_compare = [
#     'Hour', 'DEgen', 'DEload', 'DKgen', 'DKload', 'HUgen', 'HUload',
#     'ITgen', 'ITload', 'NEgen', 'NEload', 'POgen', 'POload', 'SEgen',
#     'SEload', 'SPgen', 'SPload', 'HU_surplus', 'IT_surplus', 'PO_surplus',
#     'SP_surplus', 'DE_surplus', 'DK_surplus', 'SE_surplus', 'NE_surplus',
#     'day_of_week'
# ]

# # Assuming scaled_df_train, scaled_df_val, and scaled_df_test are your DataFrames
# dfs = [scaled_df_train, scaled_df_val, scaled_df_test]
# df_names = ['scaled_df_train', 'scaled_df_val', 'scaled_df_test']

# # Plot histograms for each feature and each DataFrame
# for feature in features_to_compare:
#     plt.figure(figsize=(15, 5))
#     for i, (df, df_name) in enumerate(zip(dfs, df_names), 1):
#         plt.subplot(1, 3, i)
#         df[feature].hist(bins=20, alpha=0.7, label=df_name)
#         plt.title(f'{feature} - {df_name}')
#         plt.legend()
#     plt.show()

# %% [markdown]
# ### Creating arrays and sequences for the model

# %%
# create arrays
X_train, X_val, X_test = scaled_df_train[features].values, scaled_df_val[features].values, scaled_df_test[features].values
y_train, y_val, y_test = df_train[label_column].values, df_val[label_column].values, df_test[label_column].values


print("Shapes:")
print("X_train:", X_train.shape)
print("y_train:", y_train.shape)
print('==================')
print("X_val:", X_val.shape)
print("y_val:", y_val.shape)
print('==================')
print("X_test:", X_test.shape)
print("y_test:", y_test.shape)
# Out:
# Shapes:
# X_train: (5606, 30)
# y_train: (5606,)
# ==================
# X_val: (1402, 30)
# y_val: (1402,)
# ==================
# X_test: (1752, 30)
# y_test: (1752,)

# %%
# divide the dataset to train the model 

def create_sequences(X, y, window):
    rows = X.shape[0]
    features = X.shape[1]

    sequences = np.zeros((rows - window - 1 , window, features))
    target_values = np.zeros((rows - window - 1 ))

    for i in range(rows - window -1):

        sequences[i, : , : ] = X[ i : (i + window), : ] # cogemos las filas de i a i+window y todas las columnas (features)
        target_values[i] = y[i + window]

        # print(i)

    
    return sequences, target_values


window = 48 # The amount of hours we want to use as input data

# Usage example
sequences_train, target_values_train = create_sequences(X_train, y_train, window)
sequences_val, target_values_val = create_sequences(X_val, y_val, window)
sequences_test, target_values_test = create_sequences(X_test, y_test, window)

print("Shapes:")
print(f'rows, features: {X_train.shape}')
print('Deberiamos tener secuencias de entrenamiento = rows - window - 1: ', X_train.shape[0] - window - 1)
print("sequences_train:", sequences_train.shape)
print("target_values_train:", target_values_train.shape)
print('==================')
print("sequences_val:", sequences_val.shape)
print("target_values_val:", target_values_val.shape)
print('==================')
print("sequences_test:", sequences_test.shape)
print("target_values_test:", target_values_test.shape)
# Out:
# Shapes:
# rows, features: (5606, 30)
# Deberiamos tener secuencias de entrenamiento = rows - window - 1:  5557
# sequences_train: (5557, 48, 30)
# target_values_train: (5557,)
# ==================
# sequences_val: (1353, 48, 30)
# target_values_val: (1353,)
# ==================
# sequences_test: (1703, 48, 30)
# target_values_test: (1703,)

# %%
# print('primera secuencia de entrenamiento, primer elemento: ', sequences_train[0, 0, : ], '\n')
# print('======================================================================')
# print('debería ser igual a df_train.loc[0, features]: ',  df_train.loc[0, features], '\n')
# print('======================================================================')
# print('primer label de la primera secuencia de entrenamiento: ', target_values_train[0], '\n') 
# print('======================================================================')
# print('debería ser igual al elemento df_train.loc[window + 1,"label"]: ', df_train.loc[window + 1, 'label'])
# print('======================================================================')
# print('======================================================================')
# print('======================================================================')

# print('ultima secuencia de entrenamiento, primer fila: ', sequences_train[-1, 0, : ], '\n')
# print('======================================================================')
# print('debería ser igual a: ',  df_train.iloc[-(window+2)][features])
# print('======================================================================')
# print('label de la ultima secuencia de entrenamiento: ', target_values_train[-1], '\n') 
# print('======================================================================')
# print('debería ser igual al elemento df_train.loc[-1,"label"]: ', df_train.iloc[-1]['label'], y_train[-1])

# %%
scaled_df_test.to_csv(os.path.join('..\data\scaled_data', 'df_test.csv'))

# %% [markdown]
# ### Model

# %%
labels_countries = {
    'SP': 0, # Spain
    'UK': 1, # United Kingdom
    'DE': 2, # Germany
    'DK': 3, # Denmark
    'HU': 5, # Hungary
    'SE': 4, # Sweden
    'IT': 6, # Italy
    'PO': 7, # Poland
    'NL': 8 # Netherlands
}

# %%
target_values_train = target_values_train.astype(int)
target_values_val = target_values_val.astype(int)
target_values_test = target_values_val.astype(int)

print(target_values_train[0])
print(type(target_values_train[0]))


any_nan = np.any(np.isnan(sequences_train))
print("Are there any NaN values in sequences_train?", any_nan)
# Out:
# 3
# <class 'numpy.int32'>
# Are there any NaN values in sequences_train? False

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.callbacks import LearningRateScheduler
from tensorflow.keras.regularizers import l1
from tensorflow.compat.v1 import keras

def step_decay(epoch):
    initial_lr = 0.001
    drop = 0.5
    epochs_drop = 5
    lr = initial_lr * (drop ** (epoch // epochs_drop))
    return lr



lr_scheduler = LearningRateScheduler(step_decay)

# Define the LSTM model for classification
model = keras.models.Sequential()
model.add(keras.layers.LSTM(units=50, input_shape=(sequences_train.shape[1], sequences_train.shape[2]), kernel_regularizer=keras.regularizers.l1(0.01)))
model.add(keras.layers.Dense(units=num_countries, activation='softmax', kernel_regularizer=keras.regularizers.l1(0.01)))

# Compile the model
optimizer = Adam(learning_rate=0.001, clipvalue=1.0)
early_stopping = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)
model.compile(
    optimizer=optimizer, 
    loss='sparse_categorical_crossentropy', 
    metrics=['accuracy']
)

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_1 (LSTM)               (None, 50)                16200
#
#  dense_1 (Dense)             (None, 8)                 408
#
# =================================================================
# Total params: 16608 (64.88 KB)
# Trainable params: 16608 (64.88 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Train the model
history = model.fit(
    sequences_train, 
    target_values_train, 
    epochs=10, 
    batch_size=32, 
    validation_data=(sequences_val, target_values_val), 
    callbacks=[lr_scheduler, early_stopping]
)


# Plot training history
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# Epoch 1/10
# 174/174 [==============================] - 16s 53ms/step - loss: 2.9845 - accuracy: 0.7909 - val_loss: 1.2620 - val_accuracy: 0.7236 - lr: 0.0010
# Epoch 2/10
# 174/174 [==============================] - 8s 44ms/step - loss: 0.8955 - accuracy: 0.7981 - val_loss: 1.0143 - val_accuracy: 0.7236 - lr: 0.0010
# Epoch 3/10
# 174/174 [==============================] - 7s 42ms/step - loss: 0.7505 - accuracy: 0.8021 - val_loss: 0.9009 - val_accuracy: 0.7317 - lr: 0.0010
# Epoch 4/10
# 174/174 [==============================] - 7s 41ms/step - loss: 0.7065 - accuracy: 0.7934 - val_loss: 0.8557 - val_accuracy: 0.7236 - lr: 0.0010
# Epoch 5/10
# 174/174 [==============================] - 7s 41ms/step - loss: 0.6810 - accuracy: 0.8057 - val_loss: 0.8340 - val_accuracy: 0.7376 - lr: 0.0010
# Epoch 6/10
# 174/174 [==============================] - 6s 37ms/step - loss: 0.6585 - accuracy: 0.8073 - val_loss: 0.8208 - val_accuracy: 0.6800 - lr: 5.0000e-04
# Epoch 7/10
# 174/174 [==============================] - 7s 42ms/step - loss: 0.6492 - accuracy: 0.8076 - val_loss: 0.8400 - val_accuracy: 0.7206 - lr: 5.0000e-04
# Epoch 8/10
# 174/174 [==============================] - 7s 42ms/step - loss: 0.6415 - accuracy: 0.8110 - val_loss: 0.8182 - val_accuracy: 0.7007 - lr: 5.0000e-04
# Epoch 9/10
# 174/174 [==============================] - 8s 45ms/step - loss: 0.6367 - accuracy: 0.8100 - val_loss: 0.7985 - val_accuracy: 0.6822 - lr: 5.0000e-04
# Epoch 10/10
# 174/174 [==============================] - 8s 43ms/step - loss: 0.6294 - accuracy: 0.8177 - val_loss: 0.8087 - val_accuracy: 0.7118 - lr: 5.0000e-04

# %% [markdown]
# ### save/ load the model

# %%
#save the model 
from tensorflow.keras.models import load_model, save_model

save_path = os.path.join('..', 'models', 'model_adri_with_spain.h5')
model.save(save_path)

# Load the model
loaded_model = load_model(save_path)
# Out:
# c:\Users\adria\Documents\adriana\FORMACION\MASTER DATA SCIENCE UB\Hackathon SE\SchneiderHackathon_UBEcoFriends\.venv\lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# ### Predict and save the results

# %%
predictions = model.predict(sequences_test)
predicted_labels = np.argmax(predictions, axis=1)

print(len(predicted_labels))

# Create the desired output format
result_dict = {"target": {}}
for i, label in enumerate(predicted_labels):
    result_dict["target"][str(i + 1)] = int(label)

# Print or save the result
print(result_dict)
# Out:
# 54/54 [==============================] - 1s 16ms/step
# 1703
# {'target': {'1': 3, '2': 3, '3': 3, '4': 3, '5': 4, '6': 4, '7': 4, '8': 4, '9': 4, '10': 4, '11': 4, '12': 4, '13': 4, '14': 4, '15': 4, '16': 4, '17': 3, '18': 3, '19': 3, '20': 3, '21': 3, '22': 3, '23': 3, '24': 3, '25': 3, '26': 3, '27': 3, '28': 3, '29': 3, '30': 3, '31': 3, '32': 3, '33': 3, '34': 3, '35': 3, '36': 3, '37': 3, '38': 3, '39': 3, '40': 3, '41': 3, '42': 3, '43': 3, '44': 3, '45': 3, '46': 3, '47': 3, '48': 3, '49': 3, '50': 3, '51': 3, '52': 3, '53': 3, '54': 3, '55': 3, '56': 3, '57': 3, '58': 3, '59': 3, '60': 3, '61': 3, '62': 3, '63': 3, '64': 3, '65': 3, '66': 3, '67': 3, '68': 3, '69': 3, '70': 3, '71': 3, '72': 
, '338': 3, '339': 3, '340': 3, '341': 3, '342': 3, '343': 3, '344': 3, '345': 3, '346': 3, '347': 3, '348': 3, '349': 4, '350': 4, '351': 4, '352': 4, '353': 4, '354': 4, '355': 3, '356': 3, '357': 3, '358': 3, '359': 3, '360': 3, '361': 3, '362': 3, '363': 3, '364': 3, '365': 3, '366': 3, '367': 3, '368': 3, '369': 3, '370': 3, '371': 3, '372': 3, '373': 3, '374': 3, '375': 3, '376': 3, '377': 3, '378': 3, '379': 3, '380': 3, '381': 3, '382': 3, '383': 3, '384': 3, '385': 3, '386': 3, '387': 3, '388': 3, '389': 3, '390': 3, '391': 3, '392': 3, '393': 3, '394': 3, '395': 3, '396': 3, '397': 3, '398': 3, '399': 3, '400': 3, '401': 3, '402': 3, '403': 3, '404': 3, '405': 3, '406': 3, '407': 3, '408': 3, '409': 3, '410': ...

# %%
import json
# Specify the file path where you want to save the JSON file
json_file_path = os.path.join('..', 'predictions', 'predictions_adri_with_spain.json')

# Save the dictionary as JSON
with open(json_file_path, 'w') as json_file:
    json.dump(result_dict, json_file)

print(f"Result dictionary saved to {json_file_path}")
# Out:
# Result dictionary saved to ..\predictions\predictions_adri_with_spain.json

# %% [markdown]
# ### F1 Score

# %%
from sklearn.metrics import precision_score, recall_score, f1_score

# %%
f1 = f1_score(target_values_test.astype(int), predicted_labels)
f1
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\adria\Documents\adriana\FORMACION\MASTER DATA SCIENCE UB\Hackathon SE\SchneiderHackathon_UBEcoFriends\src\pruebas_model_adriana.ipynb Cell 34 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/adria/Documents/adriana/FORMACION/MASTER%20DATA%20SCIENCE%20UB/Hackathon%20SE/SchneiderHackathon_UBEcoFriends/src/pruebas_model_adriana.ipynb#X46sZmlsZQ%3D%3D?line=0'>1</a> f1 = f1_score(target_values_test, predicted_labels)
#       <a href='vscode-notebook-cell:/c%3A/Users/adria/Documents/adriana/FORMACION/MASTER%20DATA%20SCIENCE%20UB/Hackathon%20SE/SchneiderHackathon_UBEcoFriends/src/pruebas_model_adriana.ipynb#X46sZmlsZQ%3D%3D?line=1'>2</a> f1
#
# File c:\Users\adria\Documents\adriana\FORMACION\MASTER DATA SCIENCE UB\Hackathon SE\SchneiderHackathon_UBEcoFriends\.venv\lib\site-packages\sklearn\utils\_param_validation.py:214, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     208 try:
#     209     with config_context(
#     210         skip_parameter_validation=(
#     211             prefer_skip_nested_validation or global_skip_validation
#     212         )
#     213     ):
# --> 214         return func(*args, **kwargs)
#     215 except InvalidParameterError as e:
#     216     # When the function is just a wrapper around an estimator, we allow
#     217     # the function to delegate validation to the estimator, but we replace
#     218     # the name of the estimator by the name of the function in the error
#     219     # message to avoid confusion.
#     220     msg = re.sub(
#     221         r"parameter of \w+ must be",
#     222         f"parameter of {func.__qualname__} must be",
#     223         str(e),
#     224     )
#
# File c:\Users\adria\Documents\adriana\FORMACION\MASTER DATA SCIENCE UB\Hackathon SE\SchneiderHackathon_UBEcoFriends\.venv\lib\site-packages\sklearn\metrics\_classification.py:1239, in f1_score(y_true, y_pred, labels, pos_label, average, sample_weight, zero_division)
#    1070 @validate_params(
#    1071     {
#    1072         "y_true": ["array-like", "sparse matrix"],
#    (...)
#    1097     zero_division="warn",
#    1098 ):
#    1099     """Compute the F1 score, also known as balanced F-score or F-measure.
#    1100
#    1101     The F1 score can be interpreted as a harmonic mean of the precision and
#    (...)
#    1237     array([0.66666667, 1.        , 0.66666667])
#    1238     """
# -> 1239     return fbeta_score(
#    1240         y_true,
#    1241         y_pred,
#    1242         beta=1,
#    1243         labels=labels,
#    1244         pos_label=pos_label,
#    1245         average=average,
#    1246         sample_weight=sample_weight,
#    1247         zero_division=zero_division,
#    1248     )
#
# File c:\Users\adria\Documents\adriana\FORMACION\MASTER DATA SCIENCE UB\Hackathon SE\SchneiderHackathon_UBEcoFriends\.venv\lib\site-packages\sklearn\utils\_param_validation.py:187, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     185 global_skip_validation = get_config()["skip_parameter_validation"]
#     186 if global_skip_validation:
# --> 187     return func(*args, **kwargs)
#     189 func_sig = signature(func)
#     191 # Map *args/**kwargs to the function signature
#
# File c:\Users\adria\Documents\adriana\FORMACION\MASTER DATA SCIENCE UB\Hackathon SE\SchneiderHackathon_UBEcoFriends\.venv\lib\site-packages\sklearn\metrics\_classification.py:1413, in fbeta_score(y_true, y_pred, beta, labels, pos_label, average, sample_weight, zero_division)
#    1251 @validate_params(
#    1252     {
#    1253         "y_true": ["array-like", "sparse matrix"],
#    (...)
#    1280     zero_division="warn",
#    1281 ):
#    1282     """Compute the F-beta score.
#    1283
#    1284     The F-beta score is the weighted harmonic mean of precision and recall,
#    (...)
#    1410     0.38...
#    1411     """
# -> 1413     _, _, f, _ = precision_recall_fscore_support(
#    1414         y_true,
#    1415         y_pred,
#    1416         beta=beta,
#    1417         labels=labels,
#    1418         pos_label=pos_label,
#    1419         average=average,
#    1420         warn_for=("f-score",),
#    1421         sample_weight=sample_weight,
#    1422         zero_division=zero_division,
#    1423     )
#    1424     return f
#
# File c:\Users\adria\Documents\adriana\FORMACION\MASTER DATA SCIENCE UB\Hackathon SE\SchneiderHackathon_UBEcoFriends\.venv\lib\site-packages\sklearn\utils\_param_validation.py:187, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     185 global_skip_validation = get_config()["skip_parameter_validation"]
#     186 if global_skip_validation:
# --> 187     return func(*args, **kwargs)
#     189 func_sig = signature(func)
#     191 # Map *args/**kwargs to the function signature
#
# File c:\Users\adria\Documents\adriana\FORMACION\MASTER DATA SCIENCE UB\Hackathon SE\SchneiderHackathon_UBEcoFriends\.venv\lib\site-packages\sklearn\metrics\_classification.py:1724, in precision_recall_fscore_support(y_true, y_pred, beta, labels, pos_label, average, warn_for, sample_weight, zero_division)
#    1566 """Compute precision, recall, F-measure and support for each class.
#    1567
#    1568 The precision is the ratio ``tp / (tp + fp)`` where ``tp`` is the number of
#    (...)
#    1721  array([2, 2, 2]))
#    1722 """
#    1723 zero_division_value = _check_zero_division(zero_division)
# -> 1724 labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#    1726 # Calculate tp_sum, pred_sum, true_sum ###
#    1727 samplewise = average == "samples"
#
# File c:\Users\adria\Documents\adriana\FORMACION\MASTER DATA SCIENCE UB\Hackathon SE\SchneiderHackathon_UBEcoFriends\.venv\lib\site-packages\sklearn\metrics\_classification.py:1501, in _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#    1498 if average not in average_options and average != "binary":
#    1499     raise ValueError("average has to be one of " + str(average_options))
# -> 1501 y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#    1502 # Convert to Python primitive type to avoid NumPy type / Python str
#    1503 # comparison. See https://github.com/numpy/numpy/issues/6784
#    1504 present_labels = unique_labels(y_true, y_pred).tolist()
#
# File c:\Users\adria\Documents\adriana\FORMACION\MASTER DATA SCIENCE UB\Hackathon SE\SchneiderHackathon_UBEcoFriends\.venv\lib\site-packages\sklearn\metrics\_classification.py:84, in _check_targets(y_true, y_pred)
#      57 def _check_targets(y_true, y_pred):
#      58     """Check that y_true and y_pred belong to the same classification task.
#      59
#      60     This converts multiclass or binary types to a common shape, and raises a
#    (...)
#      82     y_pred : array or indicator matrix
#      83     """
# ---> 84     check_consistent_length(y_true, y_pred)
#      85     type_true = type_of_target(y_true, input_name="y_true")
#      86     type_pred = type_of_target(y_pred, input_name="y_pred")
#
# File c:\Users\adria\Documents\adriana\FORMACION\MASTER DATA SCIENCE UB\Hackathon SE\SchneiderHackathon_UBEcoFriends\.venv\lib\site-packages\sklearn\utils\validation.py:407, in check_consistent_length(*arrays)
#     405 uniques = np.unique(lengths)
#     406 if len(uniques) > 1:
# --> 407     raise ValueError(
#     408         "Found input variables with inconsistent numbers of samples: %r"
#     409         % [int(l) for l in lengths]
#     410     )
#
# ValueError: Found input variables with inconsistent numbers of samples: [1353, 1703]
